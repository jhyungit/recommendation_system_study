# %% [markdown]
# ## 4.4 train/test 분리 MF 알고리즘

# %%
import os
import numpy as np
import pandas as pd

r_cols = ['user_id','movie_id','rating','timestamp']
ratings = pd.read_csv('ml-100k/u.data',
            sep = '\t',
            names = r_cols,
            encoding='latin1')
            
# timestamp 제거
ratings = ratings[['user_id', 'movie_id', 'rating']].astype(int)

# train/test set 분리
from sklearn.utils import shuffle
train_size = 0.75
# (사용자 - 영화 - 평점)
ratubgs = shuffle(ratings,random_state=2021)
cutoff = int(train_size * len(ratings))
ratings_train = ratings.iloc[:cutoff]
ratings_test = ratings.iloc[cutoff:]

class NEW_MF():
    def __init__(self, ratings, hyper_params):
        self.R = np.array(ratings)
        # 사용자 수(num_users), 아이템 수(num_items)를 받아온다.
        self.num_users, self.num_items = np.shape(self.R)
        # 아래는 MF weight 조절을 위한 하이퍼파라미터이다.
        # K : 잠재요인(latent factor)의 수
        self.K = hyper_params['K']
        # alpha : 학습률
        self.alpha = hyper_params['alpha']
        # beta : 정규화 계수
        self.beta = hyper_params['beta']
        # iterations : SGD의 계산을 할 때 반복 횟수
        self.iterations = hyper_params['iterations']
        # verbose : SGD의 학습 과정을 중간중간에 출력할 것인지에 대한 여부
        self.verbose = hyper_params['verbose']
        
        item_id_index = []
        index_item_id = []
        for i, one_id in enumerate(ratings):
            item_id_index.append([one_id, i])
            index_item_id.append([i, one_id])
        self.item_id_index = dict(item_id_index)
        self.index_item_id = dict(index_item_id)
        
        user_id_index = []
        index_user_id = []
        for i, one_id in enumerate(ratings.T):
            user_id_index.append([one_id, i])
            index_user_id.append([i, one_id])
        self.user_id_index = dict(user_id_index)
        self.index_user_id = dict(index_user_id)

    def rmse(self):
        # self.R에서 평점이 있는(0이 아닌) 요소의 인덱스를 가져온다.
        xs, ys = self.R.nonzero()
        # prediction과 error를 담을 리스트 변수 초기화
        self.predictions = []
        self.errors = []
        
        # 평점이 있는 요소(사용자 x, 아이템 y) 각각에 대해서 아래의 코드를 실행한다.
        for x,y in zip(xs, ys):
            # 사용자 x, 아이템 y에 대해서 평점 예측치를 get_prediction() 함수를 사용해 계산한다.
            prediction = self.get_prediction(x,y)
            # 예측값을 예측갑 리스트에 추가한다.
            self.predictions.append(prediction)
            # 오차값을 리스트에 추가
            self.errors.append(self.R[x,y] - prediction)
        
        # 예측값 리스트와 오차값 리스트를 numpy array 형태로 변환한다.
        self.predictions = np.array(self.predictions)
        self.errors = np.array(self.errors)
        
        # error를 활용해서 RMSE 도출
        return np.sqrt(np.mean(self.errors ** 2))
    
    def sgd(self):
        for i, j, r in self.samples:
            # 사용자 i, 아이템 j에 대한 평점 예측치 계산
            prediction = self.get_prediction(i,j)
            # 실제 평점과 비교한 오차 계산
            e = (r-prediction)
            
            # 사용자 평가 경향 계산 및 업데이터
            self.b_u[i] += self.alpha * (e - (self.beta * self.b_u[i]))
            # 아이템 평가 경향 계산 및 업데이터
            self.b_d[j] += self.alpha * (e - (self.beta * self.b_d[j]))

            # P 행렬 계산 및 업데이트
            self.P[i,:] += self.alpha * ((e * self.Q[j,:]) - (self.beta * self.P[i,:]))
            # Q 행렬 계산 및 업데이트
            self.Q[j,:] += self.alpha * ((e * self.P[i,:]) - (self.beta * self.Q[j,:]))
        
    def get_prediction(self, i, j):
        # 사용자 i, 아이템 j에 대한 평점 예측치를 앞에서 배웠던 식을 이용해서 구한다.
        prediction = self.b + self.b_u[i] + self.b_d[j] + self.P[i,:].dot(self.Q[j,:].T)
        return prediction
        
    # test set 선정
    def set_test(self, ratings_test):
        test_set = []
        for i in range(len(ratings_test)):
            x = self.user_id_index[ratings_test.iloc[i,0]]
            y = self.item_id_index[ratings_test.iloc[i,0]]
            z = ratings_test.iloc[i,2]
            test_set.append([x,y,z])
            self.R[x,y] = 0
        self.test_set = test_set
        return test_set
        
    # test set RMSE 계산
    def test_rmse(self):
        error = 0
        for one_set in self.test_set:
            predicted = self.get_prediction(one_set[0], one_set[1])
            error += pow(one_set[2]-predicted, 2)
        return np.sqrt(error/len(self.test_set))
    
    def test(self):
        self.P = np.random.normal(scale = 1./self.K, size = (self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size = (self.num_items, self.K))
        self.b_u = np.zeros(self.num_users)
        self.b_d = np.zeros(self.num_items)
        self.b = np.mean(self.R[self.R.nonzero()])
        
        rows, columns = self.R.nonzero()
        self.samples = [(i,j,self.R[i,j])for i,j in zip(rows, columns)]
        
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            self.sgd()
            rmse1 = self.rmse()
            rmse2 = self.test_rmse()
            training_process.append((i+1, rmse1, rmse2))
            if self.verbose:
                if (i+1) % 10 == 0:
                    print('Iteration : %d ; Train RMSE = %.4f ; test RMSE = %.4f'% (i+1, rmse1, rmse2))
        return training_process
        
    def get_one_prediction(self,user_id,item_id):
        return self.get_prediction(self.user_id_index[user_id],
                                    self.item_id_index[item_id])
                                    
    def full_prediction(self):
        return self.b + self.b_u[:, np.newaxis] + self.b_d[np.newaxis, :] + self.P.dot(self.Q.T)
    
R_temp = ratings.pivot(index = 'user_id',
                        columns='movie_id',
                        values='rating').fillna(0)
                        
hyper_params = {
    'K' : 30, # 잠재요인 변수
    'alpha' : 0.001, # lr
    'beta' : 0.02, # 정규화 개수
    'iterations' : 100, # 반복
    'verbose' : True
}

mf = NEW_MF(R_temp, hyper_params)
test_set = mf.set_test(ratings_test)
result = mf.test()
# Out:
# Iteration : 10 ; Train RMSE = 0.9586 ; test RMSE = 1.0748
# Iteration : 20 ; Train RMSE = 0.9374 ; test RMSE = 1.0943
# Iteration : 30 ; Train RMSE = 0.9281 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9226 ; test RMSE = 1.1244
# Iteration : 50 ; Train RMSE = 0.9186 ; test RMSE = 1.1347
# Iteration : 60 ; Train RMSE = 0.9148 ; test RMSE = 1.1429
# Iteration : 70 ; Train RMSE = 0.9106 ; test RMSE = 1.1493
# Iteration : 80 ; Train RMSE = 0.9048 ; test RMSE = 1.1547
# Iteration : 90 ; Train RMSE = 0.8966 ; test RMSE = 1.1593
# Iteration : 100 ; Train RMSE = 0.8853 ; test RMSE = 1.1637

# %%
print(mf.full_prediction())
# Out:
# [[3.78270395 3.21656057 3.16850499 ... 3.3415834  3.4518325  3.43572896]
#  [3.90592312 3.35096674 3.13393813 ... 3.39080343 3.50857078 3.49420265]
#  [3.3531714  2.79977831 2.58888478 ... 2.82167543 2.93662211 2.91091564]
#  ...
#  [4.23013939 3.64965505 3.42637216 ... 3.65587521 3.77654944 3.74327041]
#  [4.3551326  3.75716628 3.56069543 ... 3.80279224 3.92469458 3.8847969 ]
#  [3.78232909 3.24660275 2.97042468 ... 3.2496531  3.40118063 3.36613143]]

# %%
print(mf.get_one_prediction(1,2))
# Out:
# 3.2165605664722543

# %% [markdown]
# # 4.5 MF의 최적 파라미터 찾기

# %%
results = []
index = []

R_temp = ratings.pivot(index = 'user_id',
                        columns='movie_id',
                        values='rating').fillna(0)

for K in range(50, 261, 10):
    print(f'K : {K}')
    hyper_params = { 
        'K' : K, # 잠재요인 변수
        'alpha' : 0.001, # lr
        'beta' : 0.02, # 정규화 개수
        'iterations' : 300, # 반복
        'verbose' : True
    }
    mf = NEW_MF(R_temp,
        hyper_params)
    test_set = mf.set_test(ratings_test)
    result = mf.test()
    index.append(K)
    results.append(result)
# Out:
# K : 50
# Iteration : 10 ; Train RMSE = 0.9588 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9379 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9288 ; test RMSE = 1.1111
# Iteration : 40 ; Train RMSE = 0.9236 ; test RMSE = 1.1244
# Iteration : 50 ; Train RMSE = 0.9199 ; test RMSE = 1.1347
# Iteration : 60 ; Train RMSE = 0.9167 ; test RMSE = 1.1428
# Iteration : 70 ; Train RMSE = 0.9133 ; test RMSE = 1.1493
# Iteration : 80 ; Train RMSE = 0.9086 ; test RMSE = 1.1547
# Iteration : 90 ; Train RMSE = 0.9018 ; test RMSE = 1.1593
# Iteration : 100 ; Train RMSE = 0.8921 ; test RMSE = 1.1640
# Iteration : 110 ; Train RMSE = 0.8795 ; test RMSE = 1.1690
# Iteration : 120 ; Train RMSE = 0.8649 ; test RMSE = 1.1746
# Iteration : 130 ; Train RMSE = 0.8492 ; test RMSE = 1.1804
# Iteration : 140 ; Train RMSE = 0.8324 ; test RMSE = 1.1854
# Iteration : 150 ; Train RMSE = 0.8145 ; test RMSE = 1.1900
# Iteration : 160 ; Train RMSE = 0.7954 ; test RMSE = 1.1945
# Iteration : 170 ; Train RMSE = 0.7755 ; test RMSE = 1.1989
# Iteration : 180 ; Train RMSE = 0.7550 ; test RMSE = 1.2032
# Iteration : 190 ; Train RMSE = 0.7342 ; test RMSE = 1.2073
# Iteration : 200 ; Train RMSE = 0.7132 ; test RMSE = 1.2113
# Iteration : 210 ; Train RMSE = 0.6925 ; test RMSE = 1.2154
# Iteration : 220 ; Train RMSE = 0.6723 ; test RMSE = 1.2192
# Iteration : 230 ; Train RMSE = 0.6526 ; test RMSE = 1.2228
# Iteration : 240 ; Train RMSE = 0.6338 ; test RMSE = 1.2262
# Iteration : 250 ; Train RMSE = 0.6159 ; test RMSE = 1.2296
# Iteration : 260 ; Train RMSE = 0.5990 ; test RMSE = 1.2327
# Iteration : 270 ; Train RMSE = 0.5831 ; test RMSE = 1.2357
# Iteration : 280 ; Train RMSE = 0.5682 ; test RMSE = 1.2385
# Iteration : 290 ; Train RMSE = 0.5543 ; test RMSE = 1.2411
# Iteration : 300 ; Train RMSE = 0.5412 ; test RMSE = 1.2436
# K : 60
# Iteration : 10 ; Train RMSE = 0.9588 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9380 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9290 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9239 ; test RMSE = 1.1245
# Iteration : 50 ; Train RMSE = 0.9204 ; test RMSE = 1.1347
# Iteration : 60 ; Train RMSE = 0.9175 ; test RMSE = 1.1429
# Iteration : 70 ; Train RMSE = 0.9144 ; test RMSE = 1.1494
# Iteration : 80 ; Train RMSE = 0.9105 ; test RMSE = 1.1546
# Iteration : 90 ; Train RMSE = 0.9049 ; test RMSE = 1.1592
# Iteration : 100 ; Train RMSE = 0.8965 ; test RMSE = 1.1634
# Iteration : 110 ; Train RMSE = 0.8851 ; test RMSE = 1.1677
# Iteration : 120 ; Train RMSE = 0.8713 ; test RMSE = 1.1726
# Iteration : 130 ; Train RMSE = 0.8559 ; test RMSE = 1.1776
# Iteration : 140 ; Train RMSE = 0.8393 ; test RMSE = 1.1818
# Iteration : 150 ; Train RMSE = 0.8213 ; test RMSE = 1.1854
# Iteration : 160 ; Train RMSE = 0.8021 ; test RMSE = 1.1887
# Iteration : 170 ; Train RMSE = 0.7818 ; test RMSE = 1.1922
# Iteration : 180 ; Train RMSE = 0.7609 ; test RMSE = 1.1959
# Iteration : 190 ; Train RMSE = 0.7394 ; test RMSE = 1.1997
# Iteration : 200 ; Train RMSE = 0.7177 ; test RMSE = 1.2035
# Iteration : 210 ; Train RMSE = 0.6961 ; test RMSE = 1.2073
# Iteration : 220 ; Train RMSE = 0.6747 ; test RMSE = 1.2110
# Iteration : 230 ; Train RMSE = 0.6538 ; test RMSE = 1.2145
# Iteration : 240 ; Train RMSE = 0.6335 ; test RMSE = 1.2179
# Iteration : 250 ; Train RMSE = 0.6140 ; test RMSE = 1.2211
# Iteration : 260 ; Train RMSE = 0.5954 ; test RMSE = 1.2242
# Iteration : 270 ; Train RMSE = 0.5778 ; test RMSE = 1.2273
# Iteration : 280 ; Train RMSE = 0.5611 ; test RMSE = 1.2302
# Iteration : 290 ; Train RMSE = 0.5454 ; test RMSE = 1.2332
# Iteration : 300 ; Train RMSE = 0.5306 ; test RMSE = 1.2360
# K : 70
# Iteration : 10 ; Train RMSE = 0.9589 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9381 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9292 ; test RMSE = 1.1111
# Iteration : 40 ; Train RMSE = 0.9241 ; test RMSE = 1.1244
# Iteration : 50 ; Train RMSE = 0.9208 ; test RMSE = 1.1347
# Iteration : 60 ; Train RMSE = 0.9180 ; test RMSE = 1.1428
# Iteration : 70 ; Train RMSE = 0.9154 ; test RMSE = 1.1494
# Iteration : 80 ; Train RMSE = 0.9120 ; test RMSE = 1.1546
# Iteration : 90 ; Train RMSE = 0.9073 ; test RMSE = 1.1591
# Iteration : 100 ; Train RMSE = 0.9002 ; test RMSE = 1.1631
# Iteration : 110 ; Train RMSE = 0.8901 ; test RMSE = 1.1670
# Iteration : 120 ; Train RMSE = 0.8774 ; test RMSE = 1.1714
# Iteration : 130 ; Train RMSE = 0.8630 ; test RMSE = 1.1761
# Iteration : 140 ; Train RMSE = 0.8472 ; test RMSE = 1.1803
# Iteration : 150 ; Train RMSE = 0.8299 ; test RMSE = 1.1839
# Iteration : 160 ; Train RMSE = 0.8112 ; test RMSE = 1.1873
# Iteration : 170 ; Train RMSE = 0.7911 ; test RMSE = 1.1906
# Iteration : 180 ; Train RMSE = 0.7698 ; test RMSE = 1.1943
# Iteration : 190 ; Train RMSE = 0.7477 ; test RMSE = 1.1982
# Iteration : 200 ; Train RMSE = 0.7251 ; test RMSE = 1.2024
# Iteration : 210 ; Train RMSE = 0.7024 ; test RMSE = 1.2065
# Iteration : 220 ; Train RMSE = 0.6797 ; test RMSE = 1.2106
# Iteration : 230 ; Train RMSE = 0.6575 ; test RMSE = 1.2148
# Iteration : 240 ; Train RMSE = 0.6359 ; test RMSE = 1.2186
# Iteration : 250 ; Train RMSE = 0.6150 ; test RMSE = 1.2223
# Iteration : 260 ; Train RMSE = 0.5951 ; test RMSE = 1.2258
# Iteration : 270 ; Train RMSE = 0.5760 ; test RMSE = 1.2291
# Iteration : 280 ; Train RMSE = 0.5580 ; test RMSE = 1.2321
# Iteration : 290 ; Train RMSE = 0.5409 ; test RMSE = 1.2350
# Iteration : 300 ; Train RMSE = 0.5247 ; test RMSE = 1.2375
# K : 80
# Iteration : 10 ; Train RMSE = 0.9589 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9381 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9292 ; test RMSE = 1.1111
# Iteration : 40 ; Train RMSE = 0.9242 ; test RMSE = 1.1244
# Iteration : 50 ; Train RMSE = 0.9209 ; test RMSE = 1.1347
# Iteration : 60 ; Train RMSE = 0.9182 ; test RMSE = 1.1429
# Iteration : 70 ; Train RMSE = 0.9155 ; test RMSE = 1.1494
# Iteration : 80 ; Train RMSE = 0.9120 ; test RMSE = 1.1547
# Iteration : 90 ; Train RMSE = 0.9070 ; test RMSE = 1.1591
# Iteration : 100 ; Train RMSE = 0.8996 ; test RMSE = 1.1633
# Iteration : 110 ; Train RMSE = 0.8894 ; test RMSE = 1.1677
# Iteration : 120 ; Train RMSE = 0.8772 ; test RMSE = 1.1728
# Iteration : 130 ; Train RMSE = 0.8636 ; test RMSE = 1.1779
# Iteration : 140 ; Train RMSE = 0.8486 ; test RMSE = 1.1826
# Iteration : 150 ; Train RMSE = 0.8321 ; test RMSE = 1.1866
# Iteration : 160 ; Train RMSE = 0.8140 ; test RMSE = 1.1903
# Iteration : 170 ; Train RMSE = 0.7944 ; test RMSE = 1.1942
# Iteration : 180 ; Train RMSE = 0.7736 ; test RMSE = 1.1981
# Iteration : 190 ; Train RMSE = 0.7518 ; test RMSE = 1.2021
# Iteration : 200 ; Train RMSE = 0.7293 ; test RMSE = 1.2061
# Iteration : 210 ; Train RMSE = 0.7063 ; test RMSE = 1.2100
# Iteration : 220 ; Train RMSE = 0.6834 ; test RMSE = 1.2137
# Iteration : 230 ; Train RMSE = 0.6606 ; test RMSE = 1.2171
# Iteration : 240 ; Train RMSE = 0.6383 ; test RMSE = 1.2203
# Iteration : 250 ; Train RMSE = 0.6167 ; test RMSE = 1.2232
# Iteration : 260 ; Train RMSE = 0.5959 ; test RMSE = 1.2259
# Iteration : 270 ; Train RMSE = 0.5760 ; test RMSE = 1.2285
# Iteration : 280 ; Train RMSE = 0.5569 ; test RMSE = 1.2309
# Iteration : 290 ; Train RMSE = 0.5388 ; test RMSE = 1.2331
# Iteration : 300 ; Train RMSE = 0.5217 ; test RMSE = 1.2352
# K : 90
# Iteration : 10 ; Train RMSE = 0.9590 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9382 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9293 ; test RMSE = 1.1111
# Iteration : 40 ; Train RMSE = 0.9244 ; test RMSE = 1.1244
# Iteration : 50 ; Train RMSE = 0.9211 ; test RMSE = 1.1347
# Iteration : 60 ; Train RMSE = 0.9185 ; test RMSE = 1.1429
# Iteration : 70 ; Train RMSE = 0.9160 ; test RMSE = 1.1493
# Iteration : 80 ; Train RMSE = 0.9130 ; test RMSE = 1.1547
# Iteration : 90 ; Train RMSE = 0.9086 ; test RMSE = 1.1590
# Iteration : 100 ; Train RMSE = 0.9021 ; test RMSE = 1.1630
# Iteration : 110 ; Train RMSE = 0.8926 ; test RMSE = 1.1670
# Iteration : 120 ; Train RMSE = 0.8807 ; test RMSE = 1.1717
# Iteration : 130 ; Train RMSE = 0.8672 ; test RMSE = 1.1766
# Iteration : 140 ; Train RMSE = 0.8524 ; test RMSE = 1.1812
# Iteration : 150 ; Train RMSE = 0.8363 ; test RMSE = 1.1854
# Iteration : 160 ; Train RMSE = 0.8187 ; test RMSE = 1.1895
# Iteration : 170 ; Train RMSE = 0.7996 ; test RMSE = 1.1936
# Iteration : 180 ; Train RMSE = 0.7792 ; test RMSE = 1.1979
# Iteration : 190 ; Train RMSE = 0.7576 ; test RMSE = 1.2022
# Iteration : 200 ; Train RMSE = 0.7352 ; test RMSE = 1.2068
# Iteration : 210 ; Train RMSE = 0.7121 ; test RMSE = 1.2111
# Iteration : 220 ; Train RMSE = 0.6886 ; test RMSE = 1.2150
# Iteration : 230 ; Train RMSE = 0.6652 ; test RMSE = 1.2187
# Iteration : 240 ; Train RMSE = 0.6421 ; test RMSE = 1.2221
# Iteration : 250 ; Train RMSE = 0.6194 ; test RMSE = 1.2252
# Iteration : 260 ; Train RMSE = 0.5975 ; test RMSE = 1.2281
# Iteration : 270 ; Train RMSE = 0.5765 ; test RMSE = 1.2306
# Iteration : 280 ; Train RMSE = 0.5563 ; test RMSE = 1.2329
# Iteration : 290 ; Train RMSE = 0.5372 ; test RMSE = 1.2349
# Iteration : 300 ; Train RMSE = 0.5190 ; test RMSE = 1.2367
# K : 100
# Iteration : 10 ; Train RMSE = 0.9590 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9382 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9294 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9245 ; test RMSE = 1.1245
# Iteration : 50 ; Train RMSE = 0.9213 ; test RMSE = 1.1348
# Iteration : 60 ; Train RMSE = 0.9188 ; test RMSE = 1.1429
# Iteration : 70 ; Train RMSE = 0.9164 ; test RMSE = 1.1494
# Iteration : 80 ; Train RMSE = 0.9136 ; test RMSE = 1.1547
# Iteration : 90 ; Train RMSE = 0.9096 ; test RMSE = 1.1592
# Iteration : 100 ; Train RMSE = 0.9034 ; test RMSE = 1.1632
# Iteration : 110 ; Train RMSE = 0.8946 ; test RMSE = 1.1673
# Iteration : 120 ; Train RMSE = 0.8833 ; test RMSE = 1.1719
# Iteration : 130 ; Train RMSE = 0.8705 ; test RMSE = 1.1769
# Iteration : 140 ; Train RMSE = 0.8564 ; test RMSE = 1.1814
# Iteration : 150 ; Train RMSE = 0.8408 ; test RMSE = 1.1853
# Iteration : 160 ; Train RMSE = 0.8237 ; test RMSE = 1.1887
# Iteration : 170 ; Train RMSE = 0.8051 ; test RMSE = 1.1919
# Iteration : 180 ; Train RMSE = 0.7852 ; test RMSE = 1.1953
# Iteration : 190 ; Train RMSE = 0.7641 ; test RMSE = 1.1988
# Iteration : 200 ; Train RMSE = 0.7421 ; test RMSE = 1.2025
# Iteration : 210 ; Train RMSE = 0.7194 ; test RMSE = 1.2063
# Iteration : 220 ; Train RMSE = 0.6961 ; test RMSE = 1.2099
# Iteration : 230 ; Train RMSE = 0.6727 ; test RMSE = 1.2135
# Iteration : 240 ; Train RMSE = 0.6493 ; test RMSE = 1.2170
# Iteration : 250 ; Train RMSE = 0.6263 ; test RMSE = 1.2201
# Iteration : 260 ; Train RMSE = 0.6038 ; test RMSE = 1.2231
# Iteration : 270 ; Train RMSE = 0.5820 ; test RMSE = 1.2259
# Iteration : 280 ; Train RMSE = 0.5611 ; test RMSE = 1.2284
# Iteration : 290 ; Train RMSE = 0.5410 ; test RMSE = 1.2308
# Iteration : 300 ; Train RMSE = 0.5220 ; test RMSE = 1.2329
# K : 110
# Iteration : 10 ; Train RMSE = 0.9590 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9383 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9295 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9246 ; test RMSE = 1.1245
# Iteration : 50 ; Train RMSE = 0.9214 ; test RMSE = 1.1348
# Iteration : 60 ; Train RMSE = 0.9190 ; test RMSE = 1.1428
# Iteration : 70 ; Train RMSE = 0.9167 ; test RMSE = 1.1494
# Iteration : 80 ; Train RMSE = 0.9140 ; test RMSE = 1.1546
# Iteration : 90 ; Train RMSE = 0.9103 ; test RMSE = 1.1590
# Iteration : 100 ; Train RMSE = 0.9047 ; test RMSE = 1.1629
# Iteration : 110 ; Train RMSE = 0.8964 ; test RMSE = 1.1668
# Iteration : 120 ; Train RMSE = 0.8857 ; test RMSE = 1.1711
# Iteration : 130 ; Train RMSE = 0.8735 ; test RMSE = 1.1757
# Iteration : 140 ; Train RMSE = 0.8599 ; test RMSE = 1.1799
# Iteration : 150 ; Train RMSE = 0.8450 ; test RMSE = 1.1834
# Iteration : 160 ; Train RMSE = 0.8284 ; test RMSE = 1.1864
# Iteration : 170 ; Train RMSE = 0.8102 ; test RMSE = 1.1892
# Iteration : 180 ; Train RMSE = 0.7905 ; test RMSE = 1.1923
# Iteration : 190 ; Train RMSE = 0.7694 ; test RMSE = 1.1955
# Iteration : 200 ; Train RMSE = 0.7472 ; test RMSE = 1.1991
# Iteration : 210 ; Train RMSE = 0.7242 ; test RMSE = 1.2028
# Iteration : 220 ; Train RMSE = 0.7007 ; test RMSE = 1.2064
# Iteration : 230 ; Train RMSE = 0.6770 ; test RMSE = 1.2099
# Iteration : 240 ; Train RMSE = 0.6533 ; test RMSE = 1.2131
# Iteration : 250 ; Train RMSE = 0.6299 ; test RMSE = 1.2161
# Iteration : 260 ; Train RMSE = 0.6070 ; test RMSE = 1.2185
# Iteration : 270 ; Train RMSE = 0.5847 ; test RMSE = 1.2209
# Iteration : 280 ; Train RMSE = 0.5633 ; test RMSE = 1.2230
# Iteration : 290 ; Train RMSE = 0.5428 ; test RMSE = 1.2249
# Iteration : 300 ; Train RMSE = 0.5232 ; test RMSE = 1.2265
# K : 120
# Iteration : 10 ; Train RMSE = 0.9590 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9383 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9295 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9246 ; test RMSE = 1.1245
# Iteration : 50 ; Train RMSE = 0.9215 ; test RMSE = 1.1348
# Iteration : 60 ; Train RMSE = 0.9191 ; test RMSE = 1.1428
# Iteration : 70 ; Train RMSE = 0.9169 ; test RMSE = 1.1494
# Iteration : 80 ; Train RMSE = 0.9143 ; test RMSE = 1.1547
# Iteration : 90 ; Train RMSE = 0.9108 ; test RMSE = 1.1591
# Iteration : 100 ; Train RMSE = 0.9053 ; test RMSE = 1.1631
# Iteration : 110 ; Train RMSE = 0.8973 ; test RMSE = 1.1671
# Iteration : 120 ; Train RMSE = 0.8868 ; test RMSE = 1.1717
# Iteration : 130 ; Train RMSE = 0.8747 ; test RMSE = 1.1768
# Iteration : 140 ; Train RMSE = 0.8615 ; test RMSE = 1.1813
# Iteration : 150 ; Train RMSE = 0.8467 ; test RMSE = 1.1851
# Iteration : 160 ; Train RMSE = 0.8303 ; test RMSE = 1.1884
# Iteration : 170 ; Train RMSE = 0.8122 ; test RMSE = 1.1916
# Iteration : 180 ; Train RMSE = 0.7928 ; test RMSE = 1.1951
# Iteration : 190 ; Train RMSE = 0.7719 ; test RMSE = 1.1989
# Iteration : 200 ; Train RMSE = 0.7499 ; test RMSE = 1.2031
# Iteration : 210 ; Train RMSE = 0.7270 ; test RMSE = 1.2072
# Iteration : 220 ; Train RMSE = 0.7034 ; test RMSE = 1.2114
# Iteration : 230 ; Train RMSE = 0.6796 ; test RMSE = 1.2152
# Iteration : 240 ; Train RMSE = 0.6557 ; test RMSE = 1.2188
# Iteration : 250 ; Train RMSE = 0.6322 ; test RMSE = 1.2220
# Iteration : 260 ; Train RMSE = 0.6092 ; test RMSE = 1.2250
# Iteration : 270 ; Train RMSE = 0.5868 ; test RMSE = 1.2277
# Iteration : 280 ; Train RMSE = 0.5653 ; test RMSE = 1.2302
# Iteration : 290 ; Train RMSE = 0.5446 ; test RMSE = 1.2325
# Iteration : 300 ; Train RMSE = 0.5249 ; test RMSE = 1.2344
# K : 130
# Iteration : 10 ; Train RMSE = 0.9590 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9383 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9295 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9247 ; test RMSE = 1.1244
# Iteration : 50 ; Train RMSE = 0.9215 ; test RMSE = 1.1348
# Iteration : 60 ; Train RMSE = 0.9192 ; test RMSE = 1.1429
# Iteration : 70 ; Train RMSE = 0.9171 ; test RMSE = 1.1495
# Iteration : 80 ; Train RMSE = 0.9146 ; test RMSE = 1.1548
# Iteration : 90 ; Train RMSE = 0.9112 ; test RMSE = 1.1592
# Iteration : 100 ; Train RMSE = 0.9060 ; test RMSE = 1.1631
# Iteration : 110 ; Train RMSE = 0.8982 ; test RMSE = 1.1669
# Iteration : 120 ; Train RMSE = 0.8879 ; test RMSE = 1.1712
# Iteration : 130 ; Train RMSE = 0.8761 ; test RMSE = 1.1760
# Iteration : 140 ; Train RMSE = 0.8631 ; test RMSE = 1.1807
# Iteration : 150 ; Train RMSE = 0.8489 ; test RMSE = 1.1845
# Iteration : 160 ; Train RMSE = 0.8331 ; test RMSE = 1.1878
# Iteration : 170 ; Train RMSE = 0.8157 ; test RMSE = 1.1910
# Iteration : 180 ; Train RMSE = 0.7967 ; test RMSE = 1.1943
# Iteration : 190 ; Train RMSE = 0.7764 ; test RMSE = 1.1976
# Iteration : 200 ; Train RMSE = 0.7548 ; test RMSE = 1.2013
# Iteration : 210 ; Train RMSE = 0.7322 ; test RMSE = 1.2050
# Iteration : 220 ; Train RMSE = 0.7089 ; test RMSE = 1.2088
# Iteration : 230 ; Train RMSE = 0.6852 ; test RMSE = 1.2126
# Iteration : 240 ; Train RMSE = 0.6614 ; test RMSE = 1.2163
# Iteration : 250 ; Train RMSE = 0.6377 ; test RMSE = 1.2199
# Iteration : 260 ; Train RMSE = 0.6143 ; test RMSE = 1.2232
# Iteration : 270 ; Train RMSE = 0.5916 ; test RMSE = 1.2263
# Iteration : 280 ; Train RMSE = 0.5696 ; test RMSE = 1.2292
# Iteration : 290 ; Train RMSE = 0.5484 ; test RMSE = 1.2319
# Iteration : 300 ; Train RMSE = 0.5281 ; test RMSE = 1.2344
# K : 140
# Iteration : 10 ; Train RMSE = 0.9590 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9383 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9296 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9247 ; test RMSE = 1.1245
# Iteration : 50 ; Train RMSE = 0.9216 ; test RMSE = 1.1348
# Iteration : 60 ; Train RMSE = 0.9193 ; test RMSE = 1.1429
# Iteration : 70 ; Train RMSE = 0.9173 ; test RMSE = 1.1494
# Iteration : 80 ; Train RMSE = 0.9150 ; test RMSE = 1.1546
# Iteration : 90 ; Train RMSE = 0.9119 ; test RMSE = 1.1591
# Iteration : 100 ; Train RMSE = 0.9072 ; test RMSE = 1.1629
# Iteration : 110 ; Train RMSE = 0.9000 ; test RMSE = 1.1666
# Iteration : 120 ; Train RMSE = 0.8902 ; test RMSE = 1.1708
# Iteration : 130 ; Train RMSE = 0.8783 ; test RMSE = 1.1755
# Iteration : 140 ; Train RMSE = 0.8652 ; test RMSE = 1.1802
# Iteration : 150 ; Train RMSE = 0.8506 ; test RMSE = 1.1840
# Iteration : 160 ; Train RMSE = 0.8345 ; test RMSE = 1.1872
# Iteration : 170 ; Train RMSE = 0.8167 ; test RMSE = 1.1902
# Iteration : 180 ; Train RMSE = 0.7974 ; test RMSE = 1.1932
# Iteration : 190 ; Train RMSE = 0.7769 ; test RMSE = 1.1965
# Iteration : 200 ; Train RMSE = 0.7552 ; test RMSE = 1.2001
# Iteration : 210 ; Train RMSE = 0.7326 ; test RMSE = 1.2040
# Iteration : 220 ; Train RMSE = 0.7094 ; test RMSE = 1.2078
# Iteration : 230 ; Train RMSE = 0.6858 ; test RMSE = 1.2118
# Iteration : 240 ; Train RMSE = 0.6620 ; test RMSE = 1.2155
# Iteration : 250 ; Train RMSE = 0.6384 ; test RMSE = 1.2191
# Iteration : 260 ; Train RMSE = 0.6151 ; test RMSE = 1.2224
# Iteration : 270 ; Train RMSE = 0.5924 ; test RMSE = 1.2252
# Iteration : 280 ; Train RMSE = 0.5703 ; test RMSE = 1.2278
# Iteration : 290 ; Train RMSE = 0.5490 ; test RMSE = 1.2300
# Iteration : 300 ; Train RMSE = 0.5285 ; test RMSE = 1.2318
# K : 150
# Iteration : 10 ; Train RMSE = 0.9590 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9383 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9296 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9247 ; test RMSE = 1.1245
# Iteration : 50 ; Train RMSE = 0.9216 ; test RMSE = 1.1348
# Iteration : 60 ; Train RMSE = 0.9193 ; test RMSE = 1.1428
# Iteration : 70 ; Train RMSE = 0.9173 ; test RMSE = 1.1494
# Iteration : 80 ; Train RMSE = 0.9149 ; test RMSE = 1.1547
# Iteration : 90 ; Train RMSE = 0.9117 ; test RMSE = 1.1591
# Iteration : 100 ; Train RMSE = 0.9067 ; test RMSE = 1.1630
# Iteration : 110 ; Train RMSE = 0.8993 ; test RMSE = 1.1668
# Iteration : 120 ; Train RMSE = 0.8892 ; test RMSE = 1.1709
# Iteration : 130 ; Train RMSE = 0.8775 ; test RMSE = 1.1755
# Iteration : 140 ; Train RMSE = 0.8647 ; test RMSE = 1.1798
# Iteration : 150 ; Train RMSE = 0.8506 ; test RMSE = 1.1837
# Iteration : 160 ; Train RMSE = 0.8349 ; test RMSE = 1.1869
# Iteration : 170 ; Train RMSE = 0.8178 ; test RMSE = 1.1900
# Iteration : 180 ; Train RMSE = 0.7992 ; test RMSE = 1.1933
# Iteration : 190 ; Train RMSE = 0.7794 ; test RMSE = 1.1966
# Iteration : 200 ; Train RMSE = 0.7583 ; test RMSE = 1.2000
# Iteration : 210 ; Train RMSE = 0.7363 ; test RMSE = 1.2036
# Iteration : 220 ; Train RMSE = 0.7134 ; test RMSE = 1.2070
# Iteration : 230 ; Train RMSE = 0.6900 ; test RMSE = 1.2103
# Iteration : 240 ; Train RMSE = 0.6663 ; test RMSE = 1.2133
# Iteration : 250 ; Train RMSE = 0.6426 ; test RMSE = 1.2162
# Iteration : 260 ; Train RMSE = 0.6191 ; test RMSE = 1.2188
# Iteration : 270 ; Train RMSE = 0.5961 ; test RMSE = 1.2211
# Iteration : 280 ; Train RMSE = 0.5737 ; test RMSE = 1.2233
# Iteration : 290 ; Train RMSE = 0.5521 ; test RMSE = 1.2253
# Iteration : 300 ; Train RMSE = 0.5313 ; test RMSE = 1.2270
# K : 160
# Iteration : 10 ; Train RMSE = 0.9590 ; test RMSE = 1.0747
# Iteration : 20 ; Train RMSE = 0.9384 ; test RMSE = 1.0942
# Iteration : 30 ; Train RMSE = 0.9296 ; test RMSE = 1.1112
# Iteration : 40 ; Train RMSE = 0.9248 ; test RMSE = 1.1244
# Iteration : 50 ; Train RMSE = 0.9217 ; test RMSE = 1.1348
# Iteration : 60 ; Train RMSE = 0.9194 ; test RMSE = 1.1430
# Iteration : 70 ; Train RMSE = 0.9174 ; test RMSE = 1.1493
# Iteration : 80 ; Train RMSE = 0.9151 ; test RMSE = 1.1547
# Iteration : 90 ; Train RMSE = 0.9121 ; test RMSE = 1.1592
# Iteration : 100 ; Train RMSE = 0.9073 ; test RMSE = 1.1631
# Iteration : 110 ; Train RMSE = 0.9002 ; test RMSE = 1.1668
# Iteration : 120 ; Train RMSE = 0.8906 ; test RMSE = 1.1712
# Iteration : 130 ; Train RMSE = 0.8794 ; test RMSE = 1.1762
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [52], line 20
#      17 mf = NEW_MF(R_temp,
#      18     hyper_params)
#      19 test_set = mf.set_test(ratings_test)
# ---> 20 result = mf.test()
#      21 index.append(K)
#      22 results.append(result)
#
# Cell In [48], line 134, in NEW_MF.test(self)
#     132 for i in range(self.iterations):
#     133     np.random.shuffle(self.samples)
# --> 134     self.sgd()
#     135     rmse1 = self.rmse()
#     136     rmse2 = self.test_rmse()
#
# Cell In [48], line 87, in NEW_MF.sgd(self)
#      84 e = (r-prediction)
#      86 # 사용자 평가 경향 계산 및 업데이터
# ---> 87 self.b_u[i] += self.alpha * (e - (self.beta * self.b_u[i]))
#      88 # 아이템 평가 경향 계산 및 업데이터
#      89 self.b_d[j] += self.alpha * (e - (self.beta * self.b_d[j]))
#
# KeyboardInterrupt:

# %%
summary = []
for i in range(len(result)):
    RMSE = []
    for result in results[i]:
        RMSE.append(result[2])
    min = np.min(RMSE)
    j = RMSE.index(min)
    summary.append([index[i], j+1, RMSE[j]])

summary
